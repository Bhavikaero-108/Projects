# %% [markdown]
# ### Reading Polynomial parameters and Calculating Thermodynamic parameters
#
# The thermo class given will be used to calculate the thermodynamic parameters. Also, you'll need [thermoDataNASA-9.yaml].  This file contains two arrays for each species for two separate temperature ranges: a_lo is for $200<T<1000$ K and a_hi is for $1000<T<6000$ K. We have followed Cantera nomenclature (http://www.cantera.org/docs/sphinx/html/cti/species.html#the-nasa-9-coefficient-polynomial-parameterization).
#
#
# $$\frac{C^0_p(T)}{R_u}=a_0T^{−2}+a_1T^{−1}+a_2+a_3T+a_4T^2+a_5T^3+a_6T^4$$
#
# $$\frac{H^0(T)}{R_u T}=−a_0T^{−2}+a_1 \frac{lnT}{T}+a_2+\frac{a_3}{2}T+\frac{a_4}{3}T^2+\frac{a_5}{4}T^3+\frac{a_6}{5}T^4+\frac{a_7}{T}$$
#
# $$\frac{s^0(T)}{R_u}=−\frac{a_0}{2}T^{−2}−a_1T^{−1}+a_2 lnT+a_3T+\frac{a_4}{2}T^2+\frac{a_5}{3}T^3+\frac{a_6}{4}T^4+a_8$$
#
# where $R_u = 8.31446 J/mol/K$ is the universal gas constant.
#
# Note that Gordon and McBride start polynomial coefficient numbering at 1 and the last coeffients for enthalpy and entropy are named respectively $a_7 = b_1$ and $a_8 = b_2$. (https://ntrs.nasa.gov/api/citations/20020085330/downloads/20020085330.pdf)

# %% [markdown]
# # Thermo Properties

# %%
# Example on how to use the class thermo to calculate thermodynamics 
# quantities for a specific species.
Molecule = "O2"    
MW_molecule = 32               # kg/kmol

t = thermo(Molecule,MW_molecule) # thermo object;
Temperature = 298       #K
print('Entropy of ',Molecule,' at ',str(Temperature), 'K: ',t.s_mole(Temperature),' J/mol')
print('Enthalpy of ',Molecule,' at ',str(Temperature), 'K: ',t.h_mole(Temperature),' J/mol')
print('Specific heat of ',Molecule,' at ',str(Temperature), 'K: ',t.cp_mole(Temperature),' J/mol')
# Out:
# Entropy of  O2  at  298 K:  205.13344991630754  J/mol
# Enthalpy of  O2  at  298 K:  -4.406684233742955  J/mol
# Specific heat of  O2  at  298 K:  29.377442521060257  J/mol

# %%
# This cell of code give you an implementation of the above formulas.
import yaml
import numpy as np

class thermo:
    
    def __init__(self, species, MW) :
        """
        species: input string name of species in thermoData.yaml
        M: input (species molecular weight, kg/kmol)
        """
        
        self.Rgas = 8.31446      # J/mol*K
        self.M    = MW
    
        with open("thermoDataNASA-9.yaml") as yfile:
           yfile = yaml.safe_load(yfile)
        
        self.a_lo = yfile[species]["a_lo"]
        self.a_hi = yfile[species]["a_hi"]
        
        self.T_lo = 200.
        self.T_mid = 1000.
        self.T_hi = 6000.
        
    def cymalalo(self) :
        return self.a_lo

    def cymalahi(self) :
        return self.a_hi

    def cp_mole(self,T) :
        """
        return calorific value at cst p in units J/mol/K
        T: input (K)
        """
        if T<=self.T_mid and T>=self.T_lo :
            a = self.a_lo
        elif T>self.T_mid and T<=self.T_hi :
            a = self.a_hi
        else :
            print ("ERROR: temperature is out of range")

        cp = a[0]/T**2 + a[1]/T + a[2] + a[3]*T + a[4]*T**2.0 + a[5]*T**3 + a[6]*T**4
        
        return cp * self.Rgas
        
    #--------------------------------------------------------

    def cp_mass(self,T) :
        """
        return calorific value at cst P in units of kJ/kg/K
        T: input (K)
        """
        return self.cp_mole(T)/self.M

    #--------------------------------------------------------
    
    def h_mole(self,T) :
        """
        return enthalpy in units of J/mol
        T: input (K)
        """
        if T<=self.T_mid and T>=self.T_lo :
            a = self.a_lo
        elif T>self.T_mid and T<=self.T_hi :
            a = self.a_hi
        else :
            print ("ERROR: temperature is out of range")

        hrt = -a[0]/T**2 + a[1]*np.log(T)/T + a[2] + a[3]/2*T + a[4]/3*T**2.0 + a[5]/4*T**3 + a[6]/5*T**4 + a[7]/T
        
        return hrt * self.Rgas * T
        
    #--------------------------------------------------------

    def h_mass(self,T) :
        """
        return enthalpy in units of kJ/kg
        T: input (K)
        """
        return self.h_mole(T)/self.M

    #--------------------------------------------------------
        
    def s_mole(self,T) :
        """
        return entropy in units of J/mol/K
        T: input (K)
        """
        if T<=self.T_mid and T>=self.T_lo :
            a = self.a_lo
        elif T>self.T_mid and T<=self.T_hi :
            a = self.a_hi
        else :
            print ("ERROR: temperature is out of range")
        
        sr = -a[0]/2/T**2 - a[1]/T + a[2]*np.log(T) + a[3]*T + a[4]/2.0*T**2.0 + a[5]/3.0*T**3.0+ a[6]/4.0*T**4.0+ a[8]
        
        return sr * self.Rgas
        
    #--------------------------------------------------------

    def s_mass(self,T) :
        """
        return entropy in units of kJ/kg/K
        T: input (K)
        """
        return self.s_mole(T)/self.M

# %%
# If you wish to use this piece of code embedded in another code, you might need the following lines:
# Careful, you might need the following function the first time you are using # the code: "!pip install ipynb"
from ipynb.fs.full.ThermoPropertiesNASA import thermo

# Try it out in a new script, if it works, it should display the same results than the cell above
# If it works, just copy the content of the previous cell in your new script, and adapt it to your needs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # If you wish to use this piece of code embedded in another code, you might need the following lines:
#       2 # Careful, you might need the following function the first time you are using # the code: "!pip install ipynb"
# ----> 3 from ipynb.fs.full.ThermoPropertiesNASA import thermo
#       5 # Try it out in a new script, if it works, it should display the same results than the cell above
#       6 # If it works, just copy the content of the previous cell in your new script, and adapt it to your needs
#
# File D:\Fall 2023\Mech 652 Dynamics of combustion\P1 - Combustion thermodynamics attached files Sep 13, 2023 1225 PM\ThermoPropertiesNASA.ipynb:31
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "### Reading Polynomial parameters and Calculating Thermodynamic parameters\n",
#       8     "\n",
#       9     "The thermo class given will be used to calculate the thermodynamic parameters. Also, you'll need [thermoDataNASA-9.yaml].  This file contains two arrays for each species for two separate temperature ranges: a_lo is for $200<T<1000$ K and a_hi is for $1000<T<6000$ K. We have followed Cantera nomenclature (http://www.cantera.org/docs/sphinx/html/cti/species.html#the-nasa-9-coefficient-polynomial-parameterization).\n",
#      10     "\n",
#      11     "\n",
#      12     "$$\\frac{C^0_p(T)}{R_u}=a_0T^{−2}+a_1T^{−1}+a_2+a_3T+a_4T^2+a_5T^3+a_6T^4$$\n",
#      13     "\n",
#      14     "$$\\frac{H^0(T)}{R_u T}=−a_0T^{−2}+a_1 \\frac{lnT}{T}+a_2+\\frac{a_3}{2}T+\\frac{a_4}{3}T^2+\\frac{a_5}{4}T^3+\\frac{a_6}{5}T^4+\\frac{a_7}{T}$$\n",
#      15     "\n",
#      16     "$$\\frac{s^0(T)}{R_u}=−\\frac{a_0}{2}T^{−2}−a_1T^{−1}+a_2 lnT+a_3T+\\frac{a_4}{2}T^2+\\frac{a_5}{3}T^3+\\frac{a_6}{4}T^4+a_8$$\n",
#      17     "\n",
#      18     "where $R_u = 8.31446 J/mol/K$ is the universal gas constant.\n",
#      19     "\n",
#      20     "Note that Gordon and McBride start polynomial coefficient numbering at 1 and the last coeffients for enthalpy and entropy are named respectively $a_7 = b_1$ and $a_8 = b_2$. (https://ntrs.nasa.gov/api/citations/20020085330/downloads/20020085330.pdf)"
#      21    ]
#      22   },
#      23   {
#      24    "cell_type": "markdown",
#      25    "metadata": {},
#      26    "source": [
#      27     "# Thermo Properties\n"
#      28    ]
#      29   },
#      30   {
# ---> 31    "cell_type": "code",
#      32    "execution_count": 4,
#      33    "metadata": {},
#      34    "outputs": [
#      35     {
#      36      "name": "stdout",
#      37      "output_type": "stream",
#      38      "text": [
#      39       "Entropy of  O2  at  298 K:  205.13344991630754  J/mol\n",
#      40       "Enthalpy of  O2  at  298 K:  -4.406684233742955  J/mol\n",
#      41       "Specific heat of  O2  at  298 K:  29.377442521060257  J/mol\n"
#      42      ]
#      43     }
#      44    ],
#      45    "source": [
#      46     "# Example on how to use the class thermo to calculate thermodynamics \n",
#      47     "# quantities for a specific species.\n",
#      48     "Molecule = \"O2\"    \n",
#      49     "MW_molecule = 32               # kg/kmol\n",
#      50     "\n",
#      51     "t = thermo(Molecule,MW_molecule) # thermo object;\n",
#      52     "Temperature = 298       #K\n",
#      53     "print('Entropy of ',Molecule,' at ',str(Temperature), 'K: ',t.s_mole(Temperature),' J/mol')\n",
#      54     "print('Enthalpy of ',Molecule,' at ',str(Temperature), 'K: ',t.h_mole(Temperature),' J/mol')\n",
#      55     "print('Specific heat of ',Molecule,' at ',str(Temperature), 'K: ',t.cp_mole(Temperature),' J/mol')\n"
#      56    ]
#      57   },
#      58   {
#      59    "cell_type": "code",
#      60    "execution_count": 3,
#      61    "metadata": {},
#      62    "outputs": [],
#      63    "source": [
#      64     "# This cell of code give you an implementation of the above formulas.\n",
#      65     "import yaml\n",
#      66     "import numpy as np\n",
#      67     "\n",
#      68     "class thermo:\n",
#      69     "    \n",
#      70     "    def __init__(self, species, MW) :\n",
#      71     "        \"\"\"\n",
#      72     "        species: input string name of species in thermoData.yaml\n",
#      73     "        M: input (species molecular weight, kg/kmol)\n",
#      74     "        \"\"\"\n",
#      75     "        \n",
#      76     "        self.Rgas = 8.31446      # J/mol*K\n",
#      77     "        self.M    = MW\n",
#      78     "    \n",
#      79     "        with open(\"thermoDataNASA-9.yaml\") as yfile:\n",
#      80     "           yfile = yaml.safe_load(yfile)\n",
#      81     "        \n",
#      82     "        self.a_lo = yfile[species][\"a_lo\"]\n",
#      83     "        self.a_hi = yfile[species][\"a_hi\"]\n",
#      84     "        \n",
#      85     "        self.T_lo = 200.\n",
#      86     "        self.T_mid = 1000.\n",
#      87     "        self.T_hi = 6000.\n",
#      88     "        \n",
#      89     "    def cymalalo(self) :\n",
#      90     "        return self.a_lo\n",
#      91     "\n",
#      92     "    def cymalahi(self) :\n",
#      93     "        return self.a_hi\n",
#      94     "\n",
#      95     "    def cp_mole(self,T) :\n",
#      96     "        \"\"\"\n",
#      97     "        return calorific value at cst p in units J/mol/K\n",
#      98     "        T: input (K)\n",
#      99     "        \"\"\"\n",
#     100     "        if T<=self.T_mid and T>=self.T_lo :\n",
#     101     "            a = self.a_lo\n",
#     102     "        elif T>self.T_mid and T<=self.T_hi :\n",
#     103     "            a = self.a_hi\n",
#     104     "        else :\n",
#     105     "            print (\"ERROR: temperature is out of range\")\n",
#     106     "\n",
#     107     "        cp = a[0]/T**2 + a[1]/T + a[2] + a[3]*T + a[4]*T**2.0 + a[5]*T**3 + a[6]*T**4\n",
#     108     "        \n",
#     109     "        return cp * self.Rgas\n",
#     110     "        \n",
#     111     "    #--------------------------------------------------------\n",
#     112     "\n",
#     113     "    def cp_mass(self,T) :\n",
#     114     "        \"\"\"\n",
#     115     "        return calorific value at cst P in units of kJ/kg/K\n",
#     116     "        T: input (K)\n",
#     117     "        \"\"\"\n",
#     118     "        return self.cp_mole(T)/self.M\n",
#     119     "\n",
#     120     "    #--------------------------------------------------------\n",
#     121     "    \n",
#     122     "    def h_mole(self,T) :\n",
#     123     "        \"\"\"\n",
#     124     "        return enthalpy in units of J/mol\n",
#     125     "        T: input (K)\n",
#     126     "        \"\"\"\n",
#     127     "        if T<=self.T_mid and T>=self.T_lo :\n",
#     128     "            a = self.a_lo\n",
#     129     "        elif T>self.T_mid and T<=self.T_hi :\n",
#     130     "            a = self.a_hi\n",
#     131     "        else :\n",
#     132     "            print (\"ERROR: temperature is out of range\")\n",
#     133     "\n",
#     134     "        hrt = -a[0]/T**2 + a[1]*np.log(T)/T + a[2] + a[3]/2*T + a[4]/3*T**2.0 + a[5]/4*T**3 + a[6]/5*T**4 + a[7]/T\n",
#     135     "        \n",
#     136     "        return hrt * self.Rgas * T\n",
#     137     "        \n",
#     138     "    #--------------------------------------------------------\n",
#     139     "\n",
#     140     "    def h_mass(self,T) :\n",
#     141     "        \"\"\"\n",
#     142     "        return enthalpy in units of kJ/kg\n",
#     143     "        T: input (K)\n",
#     144     "        \"\"\"\n",
#     145     "        return self.h_mole(T)/self.M\n",
#     146     "\n",
#     147     "    #--------------------------------------------------------\n",
#     148     "        \n",
#     149     "    def s_mole(self,T) :\n",
#     150     "        \"\"\"\n",
#     151     "        return entropy in units of J/mol/K\n",
#     152     "        T: input (K)\n",
#     153     "        \"\"\"\n",
#     154     "        if T<=self.T_mid and T>=self.T_lo :\n",
#     155     "            a = self.a_lo\n",
#     156     "        elif T>self.T_mid and T<=self.T_hi :\n",
#     157     "            a = self.a_hi\n",
#     158     "        else :\n",
#     159     "            print (\"ERROR: temperature is out of range\")\n",
#     160     "        \n",
#     161     "        sr = -a[0]/2/T**2 - a[1]/T + a[2]*np.log(T) + a[3]*T + a[4]/2.0*T**2.0 + a[5]/3.0*T**3.0+ a[6]/4.0*T**4.0+ a[8]\n",
#     162     "        \n",
#     163     "        return sr * self.Rgas\n",
#     164     "        \n",
#     165     "    #--------------------------------------------------------\n",
#     166     "\n",
#     167     "    def s_mass(self,T) :\n",
#     168     "        \"\"\"\n",
#     169     "        return entropy in units of kJ/kg/K\n",
#     170     "        T: input (K)\n",
#     171     "        \"\"\"\n",
#     172     "        return self.s_mole(T)/self.M"
#     173    ]
#     174   },
#     175   {
#     176    "cell_type": "code",
#     177    "execution_count": 5,
#     178    "metadata": {},
#     179    "outputs": [
#     180     {
#     181      "ename": "ModuleNotFoundError",
#     182      "evalue": "No module named 'ipynb'",
#     183      "output_type": "error",
#     184      "traceback": [
#     185       "\u001b---------------------------------------------------------------------------\u001b",
#     186       "\u001bModuleNotFoundError\u001b                       Traceback (most recent call last)",
#     187       "Cell \u001bIn[5], line 3\u001b\n\u001b      1\u001b \u001b# If you wish to use this piece of code embedded in another code, you might need the following lines:\u001b\n\u001b      2\u001b \u001b# Careful, you might need the following function the first time you are using # the code: \"!pip install ipynb\"\u001b\n\u001b----> 3\u001b \u001bfrom\u001b \u001bipynb\u001b\u001b.\u001b\u001bfs\u001b\u001b.\u001b\u001bfull\u001b\u001b.\u001b\u001bThermoPropertiesNASA\u001b \u001bimport\u001b thermo\n\u001b      5\u001b \u001b# Try it out in a new script, if it works, it should display the same results than the cell above\u001b\n\u001b      6\u001b \u001b# If it works, just copy the content of the previous cell in your new script, and adapt it to your needs\u001b\n",
#     188       "\u001bModuleNotFoundError\u001b: No module named 'ipynb'"
#     189      ]
#     190     }
#     191    ],
#     192    "source": [
#     193     "# If you wish to use this piece of code embedded in another code, you might need the following lines:\n",
#     194     "# Careful, you might need the following function the first time you are using # the code: \"!pip install ipynb\"\n",
#     195     "from ipynb.fs.full.ThermoPropertiesNASA import thermo\n",
#     196     "\n",
#     197     "# Try it out in a new script, if it works, it should display the same results than the cell above\n",
#     198     "# If it works, just copy the content of the previous cell in your new script, and adapt it to your needs\n"
#     199    ]
#     200   },
#     201   {
#     202    "cell_type": "code",
#     203    "execution_count": 10,
#     204    "metadata": {},
#     205    "outputs": [
#     206     {
#     207      "name": "stdout",
#     208      "output_type": "stream",
#     209      "text": [
#     210       "Entropy of O2 at 298 K: 205.13344991630754 J/mol\n",
#     211       "Entropy of O2 at 308 K: 206.10392319018078 J/mol\n",
#     212       "Entropy of O2 at 318 K: 207.04512138910516 J/mol\n",
#     213       "Entropy of O2 at 328 K: 207.9590185369065 J/mol\n",
#     214       "Entropy of O2 at 338 K: 208.8474019051571 J/mol\n",
#     215       "Entropy of O2 at 348 K: 209.71189307930928 J/mol\n",
#     216       "Entropy of O2 at 358 K: 210.55396637009932 J/mol\n",
#     217       "Entropy of O2 at 368 K: 211.37496492122926 J/mol\n",
#     218       "Entropy of O2 at 378 K: 212.17611482071035 J/mol\n",
#     219       "Entropy of O2 at 388 K: 212.95853748297918 J/mol\n",
#     220       "Entropy of O2 at 398 K: 213.72326053276325 J/mol\n"
#     221      ]
#     222     }
#     223    ],
#     224    "source": [
#     225     "Molecule = \"O2\"\n",
#     226     "MW_molecule = 32\n",
#     227     "\n",
#     228     "t = thermo(Molecule,MW_molecule) \n",
#     229     "for i in range(298,400,10):\n",
#     230     "    Temperature = i\n",
#     231     "    print(f'Entropy of {Molecule} at {str(Temperature)} K: {t.s_mole(Temperature)} J/mol')"
#     232    ]
#     233   },
#     234   {
#     235    "cell_type": "code",
#     236    "execution_count": null,
#     237    "metadata": {},
#     238    "outputs": [],
#     239    "source": []
#     240   }
#     241  ],
#     242  "metadata": {
#     243   "anaconda-cloud": {},
#     244   "kernelspec": {
#     245    "display_name": "Python 3 (ipykernel)",
#     246    "language": "python",
#     247    "name": "python3"
#     248   },
#     249   "language_info": {
#     250    "codemirror_mode": {
#     251     "name": "ipython",
#     252     "version": 3
#     253    },
#     254    "file_extension": ".py",
#     255    "mimetype": "text/x-python",
#     256    "name": "python",
#     257    "nbconvert_exporter": "python",
#     258    "pygments_lexer": "ipython3",
#     259    "version": "3.11.3"
#     260   }
#     261  },
#     262  "nbformat": 4,
#     263  "nbformat_minor": 4
#     264 }
#
# NameError: name 'thermo' is not defined

# %%
Molecule = "O2"
MW_molecule = 32

t = thermo(Molecule,MW_molecule) 
for i in range(300,3000,100):
    Temperature = i
    print(f'Entropy of {Molecule} at {str(Temperature)} K: {t.s_mole(Temperature)} J/mol')
# Out:
# Entropy of O2 at 300 K: 205.329988203867 J/mol
# Entropy of O2 at 400 K: 213.87416559341253 J/mol
# Entropy of O2 at 500 K: 220.69685635552398 J/mol
# Entropy of O2 at 600 K: 226.45458706071742 J/mol
# Entropy of O2 at 700 K: 231.47052521537066 J/mol
# Entropy of O2 at 800 K: 235.92663368117968 J/mol
# Entropy of O2 at 900 K: 239.93800413664894 J/mol
# Entropy of O2 at 1000 K: 243.58584904525065 J/mol
# Entropy of O2 at 1100 K: 246.93256224421842 J/mol
# Entropy of O2 at 1200 K: 250.02293065136996 J/mol
# Entropy of O2 at 1300 K: 252.89256044378993 J/mol
# Entropy of O2 at 1400 K: 255.5713121752608 J/mol
# Entropy of O2 at 1500 K: 258.0840020235782 J/mol
# Entropy of O2 at 1600 K: 260.4512407861537 J/mol
# Entropy of O2 at 1700 K: 262.6902044938885 J/mol
# Entropy of O2 at 1800 K: 264.8152832411216 J/mol
# Entropy of O2 at 1900 K: 266.83860828304233 J/mol
# Entropy of O2 at 2000 K: 268.7704738895574 J/mol
# Entropy of O2 at 2100 K: 270.61967328045256 J/mol
# Entropy of O2 at 2200 K: 272.3937661781516 J/mol
# Entropy of O2 at 2300 K: 274.09929252402566 J/mol
# Entropy of O2 at 2400 K: 275.7419439551659 J/mol
# Entropy of O2 at 2500 K: 277.3267021187473 J/mol
# Entropy of O2 at 2600 K: 278.85795087295804 J/mol
# Entropy of O2 at 2700 K: 280.33956783655407 J/mol
# Entropy of O2 at 2800 K: 281.774999524062 J/mol
# Entropy of O2 at 2900 K: 283.1673233633247 J/mol

# %%
Molecule = "N2"
MW_molecule = 14

t = thermo(Molecule,MW_molecule) 
for i in range(300,3000,100):
    Temperature = i
    print(f'Entropy of {Molecule} at {str(Temperature)} K: {t.s_mole(Temperature)} J/mol')
